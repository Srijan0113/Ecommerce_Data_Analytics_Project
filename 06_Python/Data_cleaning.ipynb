# %%
import pandas as pd

# %%
df = pd.read_csv("cleaned_data.csv")

# %%
cleaned_df = df.copy()

# %%
cleaned_df.isnull().sum()
# Out:
# Row ID           0
# Order ID         0
# Order Date       0
# Ship Date        0
# Ship Mode        0
# Customer ID      0
# Customer Name    0
# Segment          0
# Country          0
# City             0
# State            0
# Postal Code      0
# Region           0
# Product ID       0
# Category         0
# Sub-Category     0
# Product Name     0
# Sales            0
# Quantity         0
# Discount         0
# Profit           0
# dtype: int64

# %%
cleaned_df.duplicated().sum()
# Out:
# np.int64(0)

# %%
cleaned_df["Order Date"] = pd.to_datetime(cleaned_df["Order Date"])
cleaned_df["Ship Date"] = pd.to_datetime(cleaned_df["Ship Date"])

# %%
cleaned_df[["Order Date", "Ship Date"]].dtypes
# Out:
# Order Date    datetime64[us]
# Ship Date     datetime64[us]
# dtype: object

# %%
(cleaned_df["Ship Date"] < cleaned_df["Order Date"]).sum()
# Out:
# np.int64(0)

# %%
numeric_cols = ["Sales", "Quantity", "Discount", "Profit"]

cleaned_df[numeric_cols].dtypes
# Out:
# Sales       float64
# Quantity      int64
# Discount    float64
# Profit      float64
# dtype: object

# %%
(cleaned_df["Sales"] <= 0).sum()
# Out:
# np.int64(0)

# %%
((cleaned_df["Discount"] < 0) | (cleaned_df["Discount"] > 1)).sum()
# Out:
# np.int64(0)

# %%
cleaned_df["Profit"].isnull().sum()
# Out:
# np.int64(0)

# %%
cleaned_df[numeric_cols].describe()
# Out:
#               Sales     Quantity     Discount       Profit
# count   9994.000000  9994.000000  9994.000000  9994.000000
# mean     229.858001     3.789574     0.156203    28.656896
# std      623.245101     2.225110     0.206452   234.260108
# min        0.444000     1.000000     0.000000 -6599.978000
# 25%       17.280000     2.000000     0.000000     1.728750
# 50%       54.490000     3.000000     0.200000     8.666500
# 75%      209.940000     5.000000     0.200000    29.364000
# max    22638.480000    14.000000     0.800000  8399.976000

# %%
text_cols = [
    "Order ID", "Ship Mode", "Customer ID", "Customer Name",
    "Segment", "Country", "City", "State", "Region",
    "Product ID", "Category", "Sub-Category", "Product Name"
]

for col in text_cols:
    print(col, (cleaned_df[col] != cleaned_df[col].str.strip()).sum())
# Out:
# Order ID 0
# Ship Mode 0
# Customer ID 0
# Customer Name 0
# Segment 0
# Country 0
# City 0
# State 0
# Region 0
# Product ID 0
# Category 0
# Sub-Category 0
# Product Name 0

# %%
for col in text_cols:
    cleaned_df[col] = cleaned_df[col].str.strip()

# %%
print("Categories:")
print(cleaned_df["Category"].unique())

print("\nRegions:")
print(cleaned_df["Region"].unique())

print("\nSegments:")
print(cleaned_df["Segment"].unique())

print("\nShip Modes:")
print(cleaned_df["Ship Mode"].unique())
# Out:
# Categories:
# <StringArray>
# ['Furniture', 'Office Supplies', 'Technology']
# Length: 3, dtype: str
#
# Regions:
# <StringArray>
# ['South', 'West', 'Central', 'East']
# Length: 4, dtype: str
#
# Segments:
# <StringArray>
# ['Consumer', 'Corporate', 'Home Office']
# Length: 3, dtype: str
#
# Ship Modes:
# <StringArray>
# ['Second Class', 'Standard Class', 'First Class', 'Same Day']
# Length: 4, dtype: str

# %%
print("Rows:", len(cleaned_df))
print("Columns:", len(cleaned_df.columns))
print("Missing values:", cleaned_df.isnull().sum().sum())
print("Duplicate rows:", cleaned_df.duplicated().sum())
# Out:
# Rows: 9994
# Columns: 21
# Missing values: 0
# Duplicate rows: 0

# %%
cleaned_df.to_csv("python_cleaned_data.csv", index=False)
